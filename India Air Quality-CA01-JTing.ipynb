# %% [markdown]
# # Your name: <Enter your name>
# ## Assignment Name: CA01 - Data Cleaning and Exploration of India Air Quality

# %% [markdown]
# # Program Inititialization Section
# ## Enter your import packages here

# %%
# import packages 
import pandas as pd

# %% [markdown]
# # Data File Reading Section
# ## Write code to read in data from external sources here

# %%
#read datasets
data = pd.read_csv('data.csv',encoding = "ISO-8859-1")
# Out:
# C:\Users\16263\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # Initial Data Investigation Section
#
# ## Summarized details
# ### Generate descriptive statistics that summarize the central tendency, dispersion, and shape of a dataset’s distribution, excluding NaN values.
# #### Steps:
# #### 1. Statistical Description of data (data.describe)
# #### 2. Display number of total rows and columns of the dataset (data.shape)
# #### 3. Display number of non-null values for each column (data.count)
# #### 4. Display number of null values for each column (sum of data.isnull)
# #### 5. Display range, column, number of non-null objects of each column, datatype and memory usage (data.info)
# #### 6. Display Top 10 and Bottom 10 records (head and tail)

# %%
data.describe()
data.shape
data.count()
data.info()
data.isnull().sum()
data.head(10)
data.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %% [markdown]
# ## Cleansing the dataset
# ### Dropping of less valued columns:
# 1. stn_code, agency, sampling_date, location_monitoring_agency do not add much value to the dataset in terms of information. Therefore, we can drop those columns.
#
# 2. Dropping rows where no date is available.

# %%
data.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# ...

# %%
# Cleaning up the data

#dropping columns that aren't required

# ... your code here
data.drop(['stn_code','sampling_date','location_monitoring_station','agency'], axis = 1)

# dropping rows where no date is available
# ... your code here

data.dropna(subset=['date'])
# Out:
#        stn_code       sampling_date           state   location  \
# 0         150.0  February - M021990  Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990  Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990  Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990  Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990  Andhra Pradesh  Hyderabad
# ...         ...                 ...             ...        ...
# 435734     SAMP            15-12-15     West Bengal   ULUBERIA
# 435735     SAMP            18-12-15     West Bengal   ULUBERIA
# 435736     SAMP            21-12-15     West Bengal   ULUBERIA
# 435737     SAMP            24-12-15     West Bengal   ULUBERIA
# 435738     SAMP            29-12-15     West Bengal   ULUBERIA
#
#                                            agency  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# ...

# %%
# displaying final columns (data.columns)

# ... your code here
data.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %% [markdown]
# ### Changing the types to uniform format:
#
# Notice that the ‘type’ column has values such as ‘Industrial Area’ and ‘Industrial Areas’ — both actually mean the same, so let’s remove such type of stuff and make it uniform. Replace the 'type' values with standard codes as follows:
#
# types = {
#     "Residential": "R",
#     "Residential and others": "RO",
#     "Residential, Rural and other Areas": "RRO",
#     "Industrial Area": "I",
#     "Industrial Areas": "I",
#     "Industrial": "I",
#     "Sensitive Area": "S",
#     "Sensitive Areas": "S",
#     "Sensitive": "S",
#     np.nan: "RRO"
# }
#
# data.type = data.type.replace(types)

# %%
# ... Your code here
types = { "Residential": "R", "Residential and others": "RO", "Residential, Rural and other Areas": "RRO", "Industrial Area": "I", "Industrial Areas": "I", "Industrial": "I", "Sensitive Area": "S", "Sensitive Areas": "S", "Sensitive": "S"}
data.type = data.type.replace(types)

# %%
# Display top 10 records after codification of 'types'
# ... Your code here
data.head(10)
# Out:
#   stn_code       sampling_date           state   location agency type  so2  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN  RRO  4.8
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN    I  3.1
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN  RRO  6.2
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN  RRO  6.3
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN    I  4.7
# 5    152.0     March - M031990  Andhra Pradesh  Hyderabad    NaN  RRO  6.4
# 6    150.0     April - M041990  Andhra Pradesh  Hyderabad    NaN  RRO  5.4
# 7    151.0     April - M041990  Andhra Pradesh  Hyderabad    NaN    I  4.7
# 8    152.0     April - M041990  Andhra Pradesh  Hyderabad    NaN  RRO  4.2
# 9    151.0       May - M051990  Andhra Pradesh  Hyderabad    NaN    I  4.0
#
#     no2  rspm  spm location_monitoring_station  pm2_5        date
# 0  17.4   NaN  NaN                         NaN    NaN  1990-02-01
# ...

# %% [markdown]
# ### Creating a year column
# To view the trend over a period of time, we need year values for each row and also when you see in most of the values in date column only has ‘year’ value. So, let’s create a new column holding year values. Convert the column to 'datetime' type and extract the year to populate the new column. Display Top 5 records after the conversion.

# %%
# ... Your code here
pd.to_datetime(data['date'])
data['year'] = pd.DatetimeIndex(data['date']).year
data.head(5)
# Out:
#   stn_code       sampling_date           state   location agency type  so2  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN  RRO  4.8
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN    I  3.1
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN  RRO  6.2
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN  RRO  6.3
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN    I  4.7
#
#     no2  rspm  spm location_monitoring_station  pm2_5        date    year
# 0  17.4   NaN  NaN                         NaN    NaN  1990-02-01  1990.0
# 1   7.0   NaN  NaN                         NaN    NaN  1990-02-01  1990.0
# 2  28.5   NaN  NaN                         NaN    NaN  1990-02-01  1990.0
# 3  14.7   NaN  NaN                         NaN    NaN  1990-03-01  1990.0
# 4   7.5   NaN  NaN                         NaN    NaN  1990-03-01  1990.0

# %% [markdown]
# ### Handling Missing Values
#
# The column such as SO2, NO2, rspm, spm, pm2_5 are the ones which contribute much to our analysis. So, we need to remove null from those columns to avoid inaccuracy in the prediction.
# We use the Imputer from sklearn.preprocessing to fill the missing values in every column with the mean.

# %%
# define columns of importance, which shall be used reguarly (COLS = ....)
# invoke SimpleImputer to fill missing values using 'mean' as the replacement strategy
# Display data.info after the transformation
# Display that there are no more missing values in the dataset

# ... your code here

import numpy as np
from sklearn.impute import SimpleImputer
column = ['so2','no2','rspm','spm','pm2_5']
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
data[column]=imp_mean.fit_transform(data[column])

data.head(5)
# Out:
#   stn_code       sampling_date           state   location agency type  so2  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN  RRO  4.8
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN    I  3.1
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN  RRO  6.2
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN  RRO  6.3
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN    I  4.7
#
#     no2        rspm        spm location_monitoring_station      pm2_5  \
# 0  17.4  108.832784  220.78348                         NaN  40.791467
# 1   7.0  108.832784  220.78348                         NaN  40.791467
# 2  28.5  108.832784  220.78348                         NaN  40.791467
# 3  14.7  108.832784  220.78348                         NaN  40.791467
# 4   7.5  108.832784  220.78348                         NaN  40.791467
#
#          date    year
# 0  1990-02-01  1990.0
# 1  1990-02-01  1990.0
# 2  1990-02-01  1990.0
# ...

# %% [markdown]
# ## Statewise Grouping of so2, no2, rspm, spm values
#
# Calculate median values of so2, no2, rspm, spm for each state and display in (a) as table (b) bar chart, with values sorted in ascending order. Separate section for each of the component. Use matplotlib().

# %% [markdown]
# ### so2 status

# %%
# ... Your code here
pd.options.display.float_format = '{:,.2f}'.format #for 2 decimal points
import matplotlib.pyplot as plt #importing matplot as plt 
so2_med = data.groupby(["state"])["so2"].median()
so2_med = so2_med.sort_values(ascending=True)
so2_med.plot(kind='bar',color='r')
plt.xlabel("State")
plt.ylabel("Median")
# Out:
# Text(0, 0.5, 'Median')

# %%
so2_med
# Out:
# state
# Nagaland                       2.00
# Meghalaya                      2.00
# Mizoram                        2.00
# Arunachal Pradesh              2.50
# Himachal Pradesh               3.00
# Kerala                         4.20
# Odisha                         5.00
# Jammu & Kashmir                5.00
# Telangana                      5.00
# Andhra Pradesh                 5.00
# Goa                            6.00
# Delhi                          6.30
# Rajasthan                      6.30
# Assam                          6.50
# Puducherry                     7.27
# Daman & Diu                    7.60
# Chandigarh                     7.95
# West Bengal                    8.00
# Dadra & Nagar Haveli           8.40
# Karnataka                     10.00
# Uttar Pradesh                 10.00
# Tamil Nadu                    10.00
# Punjab                        10.30
# Tripura                       10.83
# Madhya Pradesh                10.83
# Lakshadweep                   10.83
# ...

# %% [markdown]
# ### no2 status

# %%
# ... Your code here
no2_med = data.groupby(["state"])["no2"].median()
no2_med = no2_med.sort_values(ascending=True)
no2_med.plot(kind='bar',color="purple")
plt.xlabel("State")
plt.ylabel("Median")
# Out:
# Text(0, 0.5, 'Median')

# %%
no2_med
# Out:
# state
# Arunachal Pradesh              5.00
# Mizoram                        5.00
# Nagaland                       7.00
# Meghalaya                     10.00
# Goa                           11.60
# Puducherry                    13.00
# Jammu & Kashmir               13.00
# Himachal Pradesh              13.90
# Assam                         14.00
# Kerala                        14.00
# Odisha                        16.00
# Daman & Diu                   17.60
# Chandigarh                    18.00
# Dadra & Nagar Haveli          18.00
# Madhya Pradesh                19.20
# Manipur                       19.80
# Andhra Pradesh                20.00
# Tamil Nadu                    21.00
# Karnataka                     21.20
# Chhattisgarh                  21.50
# Telangana                     22.00
# Haryana                       22.75
# Gujarat                       23.00
# Lakshadweep                   25.81
# Uttarakhand                   25.81
# Tripura                       25.81
# ...

# %% [markdown]
# ### rspm status

# %%
# ... Your code here

rspm_med=data.groupby(["state"])["rspm"].median()
rspm_med = rspm_med.sort_values(ascending=True)
rspm_med.plot(kind='bar',color="g")
plt.xlabel("State")
plt.ylabel("Median")
# Out:
# Text(0, 0.5, 'Median')

# %%
rspm_med
# Out:
# state
# Sikkim                         32.00
# Mizoram                        40.00
# Puducherry                     46.00
# Kerala                         49.00
# Goa                            56.00
# Meghalaya                      57.00
# Tamil Nadu                     59.00
# Manipur                        61.00
# Karnataka                      63.00
# Arunachal Pradesh              74.50
# Andhra Pradesh                 76.00
# Assam                          77.00
# Nagaland                       78.00
# Telangana                      80.00
# Odisha                         81.00
# Himachal Pradesh               90.00
# Chandigarh                     90.00
# Dadra & Nagar Haveli           91.00
# Gujarat                        95.00
# West Bengal                    96.00
# Maharashtra                    96.00
# Tripura                       108.83
# Madhya Pradesh                108.83
# Daman & Diu                   108.83
# Chhattisgarh                  108.83
# ...

# %% [markdown]
# ### spm status

# %%
# ... Your code here
spm_med=data.groupby(["state"])["spm"].median()
spm_med = spm_med.sort_values(ascending=True)
spm_med.plot(kind='bar',color='b')
plt.xlabel("State")
plt.ylabel("Median")
# Out:
# Text(0, 0.5, 'Median')

# %%
spm_med
# Out:
# state
# Sikkim                         75.00
# Manipur                       120.50
# Puducherry                    191.00
# Goa                           199.00
# Daman & Diu                   200.50
# Andhra Pradesh                220.78
# Meghalaya                     220.78
# Mizoram                       220.78
# Nagaland                      220.78
# Odisha                        220.78
# Rajasthan                     220.78
# Tamil Nadu                    220.78
# Telangana                     220.78
# Tripura                       220.78
# Uttar Pradesh                 220.78
# Uttarakhand                   220.78
# Punjab                        220.78
# Maharashtra                   220.78
# Madhya Pradesh                220.78
# Lakshadweep                   220.78
# Arunachal Pradesh             220.78
# Assam                         220.78
# Bihar                         220.78
# Chandigarh                    220.78
# Chhattisgarh                  220.78
# ...

# %% [markdown]
# ### What is the yearly trend in a particular state, say ‘Andhra Pradesh’?
#
# Create a new dataframe containing the NO2, SO2, rspm, and spm data regarding state ‘Andhra Pradesh’ only and group it by ‘year’. Display top 5 records after.

# %%
# ... Your code here
andrha = df[df['state']=='Andhra Pradesh']
andrha_year = andrha[['so2','no2','rspm','spm','year']].groupby('year', as_index = True).median()

andrha_year.head(5)
# Out:
#            so2   no2   rspm    spm
# year
# 1,990.00  5.60 13.60 108.83 179.00
# 1,991.00  8.25 12.80 108.83 141.50
# 1,992.00 12.40 27.60 108.83 192.00
# 1,993.00  6.00 11.40 108.83 220.78
# 1,994.00  8.70 14.20 108.83 220.78

# %%
# Display yearly trend graph (year vs. value) in pairs: (a) so2 and no2 (b) rspm and spm. 
# So, you will display TWO graphs altogether.


# ... Your code here

# %%
plt.plot(andhra_year['so2'], marker = 'o', color = 'red')
plt.plot(andrha_year['no2'], marker = 'o', color = 'blue')
plt.legend(['so2','no2'])

# %%
plt.plot(andhra_year['rspm'], marker = 'o', color = 'red')
plt.plot(andrha_year['spm'], marker = 'o', color = 'blue')
plt.legend(['rspm','spm'])

# %% [markdown]
# Do you find anythumg alarming? Explain what you can conclude from this Exploratory Data Analysis for the State of Andhra Pradesh. Enter your answer here .....

# %%
#From this data analysis we can determine that the rspm and so2 over time has gone down over the years which is a good sign.
#However, despite rspm and so2 levels going down, the amount of no2 and spm levels have increased with spm specifically increasing at a dramatic rate which suggests dangerous pollutants in the air for Andhra Pradesh.
